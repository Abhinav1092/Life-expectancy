# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
data= pd.read_csv("Life expectancy.csv")
df=pd.DataFrame(data)
df.head()
# Out:
#       Entity  Year  Life expectancy
# 0  Australia  1802        34.049999
# 1  Australia  1803        34.049999
# 2  Australia  1804        34.049999
# 3  Australia  1805        34.049999
# 4  Australia  1806        34.049999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3253 entries, 0 to 3252
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Entity           3253 non-null   object
#  1   Year             3253 non-null   int64
#  2   Life expectancy  3253 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.4+ KB

# %%
x=df['Entity']
y=df['Life expectancy']
plt.barh(x,y)
plt.xlabel('Life')
plt.ylabel('entity')
# Out:
# Text(0, 0.5, 'entity')

# %%
sns.pairplot(df,hue='Entity')

# %%
df.fillna(0)
# Out:
#              Entity  Year  Life expectancy
# 0         Australia  1802        34.049999
# 1         Australia  1803        34.049999
# 2         Australia  1804        34.049999
# 3         Australia  1805        34.049999
# 4         Australia  1806        34.049999
# ...             ...   ...              ...
# 3248  United States  2012        78.940002
# 3249  United States  2013        78.959999
# 3250  United States  2014        78.940002
# 3251  United States  2015        78.870003
# 3252  United States  2016        78.860001
#
# [3253 rows x 3 columns]

# %%
df_g=sns.PairGrid(df, hue='Life expectancy')
df_g.map_diag(plt.hist)

# %%
df_m=sns.FacetGrid(df, col='Entity', col_wrap=5, height=2)
df_m.map(plt.plot, 'Year','Life expectancy',marker='.')

# %% [markdown]
# So, It can be seen that with passing of time our Life expectancy is going up.
# In 1800 people's Life expectancy was less as compared with 21st century. Every country has shown growth.
